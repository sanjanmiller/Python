# %%
import openpyxl
import pandas as pd

# %%
workbook=openpyxl.Workbook()

# %%
sheet=workbook.active

# %%
data=[
    ['NAME','DOMAIN','AGE','LOCATION','SALARY','EXP'],
    ['Alice Johnson', 'Software Engineering', 29, 'New York', 95000, 5],
['Michael Brown', 'Marketing', 34, 'London', 78000, 8],
['Emma Davis', 'Data Science', 26, 'San Francisco', 105000, 3],
['David Smith', 'Finance', 40, 'Sydney', 120000, 15],
['Sophia Taylor', 'Graphic Design', 32, 'Berlin', 65000, 7]
]
for row in data:
    sheet.append(row)

workbook.save('data.xlsx')

# %%
data
# Out:
# [['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'],
#  ['Alice Johnson', 'Software Engineering', 29, 'New York', 95000, 5],
#  ['Michael Brown', 'Marketing', 34, 'London', 78000, 8],
#  ['Emma Davis', 'Data Science', 26, 'San Francisco', 105000, 3],
#  ['David Smith', 'Finance', 40, 'Sydney', 120000, 15],
#  ['Sophia Taylor', 'Graphic Design', 32, 'Berlin', 65000, 7]]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP'

# %%
emp=pd.read_excel(r'C:\Users\HP\data.xlsx')

# %%
emp
# Out:
#             NAME                DOMAIN  AGE       LOCATION  SALARY  EXP
# 0  Alice Johnson  Software Engineering   29       New York   95000    5
# 1  Michael Brown             Marketing   34         London   78000    8
# 2     Emma Davis          Data Science   26  San Francisco  105000    3
# 3    David Smith               Finance   40         Sydney  120000   15
# 4  Sophia Taylor        Graphic Design   32         Berlin   65000    7

# %%
emp.shape
# Out:
# (5, 6)

# %%
emp.columns
# Out:
# Index(['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'], dtype='object')

# %%
len(emp.columns)
# Out:
# 6

# %%
len(emp)
# Out:
# 5

# %%
emp['SALARY']
# Out:
# 0     95000
# 1     78000
# 2    105000
# 3    120000
# 4     65000
# Name: SALARY, dtype: int64

# %%
emp['EXP']
# Out:
# 0     5
# 1     8
# 2     3
# 3    15
# 4     7
# Name: EXP, dtype: int64

# %%
emp[['SALARY','EXP']]
# Out:
#    SALARY  EXP
# 0   95000    5
# 1   78000    8
# 2  105000    3
# 3  120000   15
# 4   65000    7

# %%
import numpy as np #ND ARRAY
import matplotlib.pyplot as plt #VISUALIZATION
import seaborn as sns #STATISTIC VISUALIZATION

# %%
vis1=sns.displot(emp['SALARY'])

# %%
vis1=sns.distplot(emp['SALARY'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3960\908002005.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis1=sns.distplot(emp['SALARY'])

# %%
vis3=plt.hist(emp['SALARY'])

# %%
plt.rcParams['figure.figsize']=5,1 #5-width of the figure,1-length of the figure

# %%
vis4=sns.lmplot(data=emp,x='EXP',y='SALARY')

# %%
vis5=sns.lmplot(data=emp,x='EXP',y='SALARY',fit_reg=False)

# %%
vis5=sns.lmplot(data=emp,x='EXP',y='SALARY',fit_reg=True)
